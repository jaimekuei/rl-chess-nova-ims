# %%
import pickle
import os
from utils import load_checkpoint
import pandas as pd
import seaborn as sns

# %%
strategy = 'dqn_white_stockfish_v2'
version = 'v1'

path_metrics = os.path.join(
    os.getcwd(), 'checkpoint', strategy, version, 
    'history_metrics', 'checkpoint_game_metrics_iteration_880.pkl')

with open(path_metrics, 'rb') as f:
    metrics = pickle.load(f)

results = pd.DataFrame(metrics)
results.plot.line(x='game', y='avg_plays')
sns.regplot(x='game', y='avg_plays', data=results)

results['window_avg_plays_sum'] = results['avg_plays'].rolling(10).sum()
results.plot.line(x='game', y='window_avg_plays_sum')
sns.regplot(x='game', y='window_avg_plays_sum', data=results)

results.plot.line(x='game', y='last_reward')
sns.regplot(x='game', y='last_reward', data=results)

results.plot.line(x='game', y='cummulated_reward')
sns.regplot(x='game', y='cummulated_reward', data=results)

results['window_cummulated_reward'] = results['cummulated_reward'].rolling(10).sum()
results.plot.line(x='game', y='window_cummulated_reward')
sns.regplot(x='game', y='window_cummulated_reward', data=results)
# Out:
# <Axes: xlabel='game', ylabel='window_cummulated_reward'>

# %%
strategy = 'dqn_white_stockfish'
version = 'v6'

path_metrics = os.path.join(
    os.getcwd(), 'checkpoint', strategy, version, 
    'history_metrics', 'checkpoint_game_metrics_iteration_860.pkl')

with open(path_metrics, 'rb') as f:
    metrics = pickle.load(f)

results = pd.DataFrame(metrics)
results.plot.line(x='game', y='avg_plays')
sns.regplot(x='game', y='avg_plays', data=results)

results['window_avg_plays_sum'] = results['avg_plays'].rolling(10).sum()
results.plot.line(x='game', y='window_avg_plays_sum')
sns.regplot(x='game', y='window_avg_plays_sum', data=results)

results = pd.DataFrame(metrics)
# results.plot.line(x='game', y='cummulated_reward')
results['window_cummulated_reward'] = results['cummulated_reward'].rolling(10).sum()
results.plot.line(x='game', y='window_cummulated_reward')
sns.regplot(x='game', y='window_cummulated_reward', data=results)
# Out:
# <Axes: xlabel='game', ylabel='window_cummulated_reward'>

# %%
strategy = 'dqn_white_stockfish'
version = 'v5'

path_metrics = os.path.join(
    os.getcwd(), 'checkpoint', strategy, version, 
    'history_metrics', 'checkpoint_game_metrics_iteration_560.pkl')

with open(path_metrics, 'rb') as f:
    metrics = pickle.load(f)

results = pd.DataFrame(metrics)
results.plot.line(x='game', y='avg_plays')
sns.regplot(x='game', y='avg_plays', data=results)

results['window_avg_plays_sum'] = results['avg_plays'].rolling(10).sum()
results.plot.line(x='game', y='window_avg_plays_sum')
sns.regplot(x='game', y='window_avg_plays_sum', data=results)

results = pd.DataFrame(metrics)
# results.plot.line(x='game', y='cummulated_reward')
results['window_cummulated_reward'] = results['cummulated_reward'].rolling(10).sum()
results.plot.line(x='game', y='window_cummulated_reward')
sns.regplot(x='game', y='window_cummulated_reward', data=results)
# Out:
# <Axes: xlabel='game', ylabel='window_cummulated_reward'>

# %%
strategy = 'dqn_white_stockfish'
version = 'v4'

path_metrics = os.path.join(
    os.getcwd(), 'checkpoint', strategy, version, 
    'history_metrics', 'checkpoint_game_metrics_iteration_380.pkl')

with open(path_metrics, 'rb') as f:
    metrics = pickle.load(f)

results = pd.DataFrame(metrics)
results.plot.line(x='game', y='avg_plays')
results['window_avg_plays_sum'] = results['avg_plays'].rolling(10).sum()
results.plot.line(x='game', y='window_avg_plays_sum')
# Out:
# <Axes: xlabel='game'>

# %%
strategy = 'dqn_white_stockfish'
version = 'v2'

path_metrics = os.path.join(
    os.getcwd(), 'checkpoint', strategy, version, 
    'history_metrics', 'checkpoint_game_metrics_iteration_680.pkl')

with open(path_metrics, 'rb') as f:
    metrics = pickle.load(f)

results = pd.DataFrame(metrics)
results.plot.line(x='game', y='avg_plays')
results['window_avg_plays_sum'] = results['avg_plays'].rolling(10).sum()
results.plot.line(x='game', y='window_avg_plays_sum')
# Out:
# <Axes: xlabel='game'>

# %%
results['window_avg_plays_sum'] = results['avg_plays'].rolling(10).sum()
results.plot.line(x='game', y='window_avg_plays_sum')
# Out:
# <Axes: xlabel='game'>

# %%
strategy = 'dqn_white_stockfish'
version = 'v1'

path_metrics = os.path.join(
    os.getcwd(), 'checkpoint', strategy, version, 
    'history_metrics', 'checkpoint_game_metrics_iteration_1160.pkl')

with open(path_metrics, 'rb') as f:
    metrics = pickle.load(f)

results = pd.DataFrame(metrics)
results.plot.line(x='game', y='avg_plays')
# Out:
# <Axes: xlabel='game'>

# %%
results['window_avg_plays_sum'] = results['avg_plays'].rolling(25).sum()
# results
results.plot.line(x='game', y='window_avg_plays_sum')
# Out:
# <Axes: xlabel='game'>

# %%
results[results['cummulated_reward']>-1.8].plot.line(x='game', y='cummulated_reward')
# Out:
# <Axes: xlabel='game'>

# %%
results['window_cummulated_reward_sum'] = results['cummulated_reward'].rolling(10).sum()
# results
results[results['cummulated_reward']>-1].plot.line(x='game', y='window_cummulated_reward_sum')
# Out:
# <Axes: xlabel='game'>

# %%
strategy = 'dqn_white_stockfish_v3'
version = 'v1'

path_metrics = os.path.join(
    os.getcwd(), 'checkpoint', strategy, version, 
    'history_metrics', 'checkpoint_game_metrics_iteration_470.pkl')

with open(path_metrics, 'rb') as f:
    metrics = pickle.load(f)

results = pd.DataFrame(metrics)
results.plot.line(x='game', y='avg_plays')
# Out:
# <Axes: xlabel='game'>

# %%
strategy = 'dqn_white_stockfish_v3'
version = 'v2'

path_metrics = os.path.join(
    os.getcwd(), 'checkpoint', strategy, version, 
    'history_metrics', 'checkpoint_game_metrics_iteration_420.pkl')

with open(path_metrics, 'rb') as f:
    metrics = pickle.load(f)

results = pd.DataFrame(metrics)
results.plot.line(x='game', y='avg_plays')
# Out:
# <Axes: xlabel='game'>

# %%
strategy = 'dqn_white_stockfish_v3'
version = 'v1'

path_metrics = os.path.join(
    os.getcwd(), 'checkpoint', strategy, version, 
    'history_metrics', 'checkpoint_game_metrics_iteration_50.pkl')

with open(path_metrics, 'rb') as f:
    metrics = pickle.load(f)

results = pd.DataFrame(metrics)
results.plot.line(x='game', y='avg_plays')
# Out:
# <Axes: xlabel='game'>

# %%
strategy = 'dqn_white_stockfish_v3'
version = 'v1'

path_metrics = os.path.join(
    os.getcwd(), 'checkpoint', strategy, version, 
    'history_metrics', 'checkpoint_game_metrics_iteration_40.pkl')

with open(path_metrics, 'rb') as f:
    metrics = pickle.load(f)

results = pd.DataFrame(metrics)
results.plot.line(x='game', y='avg_plays')

# %%
strategy = 'q_learning_white_stockfish'
version = 'v1'

path_metrics = os.path.join(
    os.getcwd(), 'checkpoint', strategy, version, 
    'history_metrics', 'checkpoint_game_metrics_iteration_1780.pkl')

with open(path_metrics, 'rb') as f:
    metrics = pickle.load(f)

results = pd.DataFrame(metrics)
results.plot.line(x='game', y='avg_plays')
# Out:
# <Axes: xlabel='game'>
